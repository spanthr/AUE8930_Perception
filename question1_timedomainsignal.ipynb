# %% [markdown]
# <a href="https://colab.research.google.com/github/spanthr/AUE8930_Perception/blob/master/question1_timedomainsignal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
#from __future__ import division
Fs=1000                                                                         # sampling frequency or rate
  
N=(2-0)*Fs                                                                      #Time period
time=np.linspace(0,2,N)                                                         # time vector start,end and size
amp2=2
amp3=3

w1=500                                                                          #omega for the function
w2=1000
w3=2000


time_data=2+amp3*np.cos(w1*math.pi*time)+amp2*np.cos(w2*math.pi*time)+amp3*np.sin(w3*math.pi*time)
#noise=0                                                                         # No noise the wave

"""plotting the function"""

plt.plot(time[0:100],time_data[0:100])
plt.title('Time Domain')
plt.ylabel('Amplitude')
plt.xlabel('Time')
plt.show()

# %%
"""Analuzing the singnal in  the frequency domain"""
from scipy.fftpack import fft                                                     #import Fourier transform for converting to frequency domain

Fs=Fs/2                                                                          #Nyquist Shanon requirement
frequency=np.linspace(0.0,Fs,int(N/2))
freq_data=fft(time_data)                                                          # frequecny data for time domain using the fft function
y=2/N*np.abs(freq_data[0:np.int(N/2)])

# %%
""" Plotting the frequency domain function"""
plt.plot(frequency,y)
plt.title('Frequency domain signal')
plt.xlabel('Frequency in Hz')
plt.ylabel('Amplitude')
plt.show()
